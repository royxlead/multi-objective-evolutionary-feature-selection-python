# %% [markdown]
# # Multi-Objective Evolutionary Feature Selection Demo
# This notebook demonstrates NSGA-II-based joint feature selection and RandomForest hyperparameter optimization on medical datasets.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path('.').resolve()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from moefs.config import ExperimentConfig
from moefs.experiment import run_full_experiment

# %%
config = ExperimentConfig(
    project_root=PROJECT_ROOT,
    population_size=16,
    generations=4,
    seed=42,
    n_jobs=1,
    quick_mode=True,
    significance_min_pairs=2,
    permutation_repeats=10,
    permutation_top_k=10,
    dataset_limit=1,
    enable_feature_expansion=False,
 )
config.cv_folds = 3
config.significance_cv_splits = 2
config.significance_cv_repeats = 1

comparison_df, significance_df = run_full_experiment(config)
comparison_df.head()

# %%
import pandas as pd

summary_path = PROJECT_ROOT / 'results' / 'summary_by_method.csv'
final_table_path = PROJECT_ROOT / 'results' / 'final_comparison_table.csv'

summary_df = pd.read_csv(summary_path)
final_table_df = pd.read_csv(final_table_path)

display(summary_df)
display(final_table_df)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

plot_path = PROJECT_ROOT / 'plots' / 'wisconsin_breast_cancer_pareto_front.png'
if plot_path.exists():
    image = mpimg.imread(plot_path)
    plt.figure(figsize=(8, 6))
    plt.imshow(image)
    plt.axis('off')
    plt.title('Pareto Front Example')
    plt.show()
else:
    print(f'Plot not found yet: {plot_path}')
